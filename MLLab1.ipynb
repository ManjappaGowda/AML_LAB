# %%
x={'Tom':'tom.m@gmu.org','Bill Gates':'billgates@gmail.com'}

# %%
x['Bill Gates']
# Out:
# 'billgates@gmail.com'

# %%
x['billgates@gmail.com']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1076/2835720018.py in <cell line: 0>()
# ----> 1 x['billgates@gmail.com']
#
# KeyError: 'billgates@gmail.com'

# %%
x['Thompson']='mit@au.edu'

# %%
print(x)
# Out:
# {'Tom': 'tom.m@gmu.org', 'Bill Gates': 'billgates@gmail.com', 'Thompson': 'mit@au.edu'}

# %%
for name in x:
  print(name)
# Out:
# Tom
# Bill Gates
# Thompson

# %%
for name in x:
  print(x[name])
# Out:
# tom.m@gmu.org
# billgates@gmail.com
# mit@au.edu

# %%
for name in x.items():
  print(name)
# Out:
# ('Tom', 'tom.m@gmu.org')
# ('Bill Gates', 'billgates@gmail.com')
# ('Thompson', 'mit@au.edu')

# %%
for name,email in x.items():
  print(name)
  print(email)
# Out:
# Tom
# tom.m@gmu.org
# Bill Gates
# billgates@gmail.com
# Thompson
# mit@au.edu

# %%
#unpacking a sequence into differenty variable
x=('Tom','Michel','tom.m@gmu.org')
fname,lname,email=x
lname
# Out:
# 'Michel'

# %%
x
# Out:
# ('Tom', 'Michel', 'tom.m@gmu.org')

# %%
x=('Tom','Michel','tom.m@gmu.org','ca')
fname,lname,email,cname=x

# %%
cname
# Out:
# 'ca'

# %%
#Python has a built in method for converting streing formating
sales_record={
    'price':3.24,
    'num_items':4,
    'person':'Tom',
    'email':'tom.m@gmu.org'}

# %%
sales_statement='{} bought {} item(s) at a price of INR {} each for a total of INR {}'

# %%
print(sales_statement.format(sales_record['person'],
                             sales_record['num_items'],
                             sales_record['price'],
                             sales_record['num_items']*sales_record['price']))
# Out:
# Tom bought 4 item(s) at a price of INR 3.24 each for a total of INR 12.96

# %%
import datetime as dt
import time as tm

# %%
#time returns current time in seconds since the epoch(january 1st.1970)
tm.time()
# Out:
# 1785993054.33096

# %%
from datetime import date
from datetime import time
from datetime import datetime

# %%
today=date.today()
print('today date is',today)
# Out:
# today date is 2026-08-06

# %%
dtnow=dt.datetime.fromtimestamp(tm.time())
dtnow
# Out:
# datetime.datetime(2026, 8, 6, 5, 13, 56, 294262)

# %%
dtnow.year
# Out:
# 2026

# %%
#timedelta is a duration expreessing the difference betwwen the two dates
delta=dt.timedelta(days=120)

# %%
#date.todayu returnms the current local date
today=dt.date.today()

# %%
today-delta# the date 100 days ago
# Out:
# datetime.date(2026, 4, 8)

# %%
today>today-delta
# Out:
# True

# %%
#example for class
class Person:
  institute="Manipal school of Information science"# a class variable

  #self keyword to access the atribute and methods of the class

  def set_name(self,new_name): #a Method
    self.name=new_name
  def set_location(self,new_location):
    self.location=new_location

# %%
person=Person()
person.set_name('Manjappa Gowda')
person.set_location('Chikkamagalur,karnataka')

# %%
print('{} lives in {} and studying in the institute {}'.format(person.name,person.location,person.institute))
# Out:
# Manjappa Gowda lives in Chikkamagalur,karnataka and studying in the institute Manipal school of Information science

# %%
# example for set
x={1,'x',2,'y',(1,2,3),'hello'}
type(x)
# Out:
# set

# %%
y=(1,2,3)
type(y)
# Out:
# tuple

# %%
#sets are unordered
y={'one','x',2,'y',3}
z={1,'x','two','y','a'}
print(y,z)
# Out:
# {2, 3, 'x', 'one', 'y'} {1, 'two', 'x', 'y', 'a'}

# %%
#Add a value to the set
y.add(4)

# %%
y
# Out:
# {2, 3, 4, 'one', 'x', 'y'}

# %%
#example for the mapping function between the three lists

store1=[10.00,11.00,12.34,5.34]
store2=[19.00,10,10,12.34,5.01]
store3=[15.00,12.00,11.00,6.00]
cheapest=map(min,store1,store2,store3)
cheapest

# %%
#iterate map object to see the value
for item in cheapest:
  print(item)
# Out:
# 10.0
# 10
# 10
# 5.34

# %%
def calculateSquare(n):
  return n*n

# %%
numbers=(1,2,3,4)
result=map(calculateSquare,numbers)
print(result)

# %%
res=list(result)
print(res)
# Out:
# [1, 4, 9, 16]

# %%
# Original list of numbers
numbers = [1, 2, 3, 4, 5]

# Apply lambda function to square each number
squared_numbers = list(map(lambda x: x ** 2, numbers))

print(squared_numbers)
# Output: [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %%
# Define two lists of numbers
list1 = [1, 2, 3, 4]
list2 = [10, 20, 30, 40]

# Use map() with a two-argument lambda function
# The lambda takes 'x' from list1 and 'y' from list2 simultaneously
result_map = map(lambda x, y: x + y, list1, list2)

# Convert the map object back into a list to see the results
result_list = list(result_map)

print(result_list)
# Output: [11, 22, 33, 44]
# Out:
# [11, 22, 33, 44]

# %%
people=['python programing language','computer lab test','ram scored 100','sam scored 99']

def split_title_and_name(person
                         )
